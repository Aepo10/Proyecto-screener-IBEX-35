# %% [markdown]
# En esta primera parte analizaré la información que puedo obtener de la base de datos. La API usada es https://profit.com/es/ y en primer lugar comprobaré de que índices bursatiles puedo sacar información.

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (0.2.55)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from yfinance) (4.3.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ganad\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\ganad\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importamos lo necesario para trabajar con la API Profit.com y seteamos 
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import datetime
import time
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Creo también el archivo tokens.env que añadiré al gitignore para que no suba a git y en el que guardaré los dos tokens que tengo de mi API.

# %%
import os
from dotenv import load_dotenv

# Ruta al archivo tokens.env (asumiendo que está en la misma carpeta que el notebook)
load_dotenv("tokens.env")

# Acceder a tus tokens
api_key = os.getenv("API_KEY")
otro_token = os.getenv("API_KEY_2")  # cambia el nombre según tus claves reales

print("API Key cargada:", api_key is not None)
# Out:
# API Key cargada: True

# %% [markdown]
# La URL de la API, siguiendo los datos obtenidos de la documentación, cambia en función de los datos que queramos obtener por lo que voy a ir definiendo diferentes variables en función de los datos que quiera obtener. la información de la API está completa en: https://api.profit.com/#tag/Reference-Data

# %%
#Definimos la URL de la API para ver los índices que podemos sacar
URL_INDEX = f"https://api.profit.com/data-api/reference/indices?token=" + api_key
URL_INDEX
# Out:
# 'https://api.profit.com/data-api/reference/indices?token=978336172b8c4b29960d9366896f6ef7'

# %%
#Creo la request para ver los índices disponibles y le meto un código de error si no funciona
response = requests.get(URL_INDEX)
if response.status_code == 200:
    data = response.json()
else:
    print(f"Error: {response.status_code} - {response.text}")

#Vemos los índices disponibles
data
# Out:
# {'data': [{'ticker': 'NDX.INDX',
#    'symbol': 'NDX',
#    'name': 'Nasdaq 100',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'GSPC.INDX',
#    'symbol': 'GSPC',
#    'name': 'S&P 500 Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DJI.INDX',
#    'symbol': 'DJI',
#    'name': 'Dow Jones Industrial Average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NAS100.OANDA',
#    'symbol': 'NAS100',
#    'name': 'US Nas 100',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'OANDA'},
#   {'ticker': 'SPX500.OANDA',
#    'symbol': 'SPX500',
#    'name': 'US SPX 500',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'OANDA'},
#   {'ticker': 'US500.ICMARKETS',
#    'symbol': 'US500',
#    'name': 'USA S&P 500 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'US30.ICMARKETS',
#    'symbol': 'US30',
#    'name': 'USA Dow Jones IA Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'US30.OANDA',
#    'symbol': 'US30',
#    'name': 'US Wall St 30',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'OANDA'},
#   {'ticker': 'USDX.PEPPERSTONE',
#    'symbol': 'USDX',
#    'name': 'US Dollar Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'JP225.ICMARKETS',
#    'symbol': 'JP225',
#    'name': 'Japan Nikkei 225 Index',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'USTEC.ICMARKETS',
#    'symbol': 'USTEC',
#    'name': 'USA NASDAQ 100 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'USTEC.PEPPERSTONE',
#    'symbol': 'USTEC',
#    'name': 'US Tech 100 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'JPN225.FXPIG',
#    'symbol': 'JPN225',
#    'name': 'Nikkei 225 Index',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'FXPIG'},
#   {'ticker': 'DE30.ICMARKETS',
#    'symbol': 'DE30',
#    'name': 'German DAX 30 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'DE30.PEPPERSTONE',
#    'symbol': 'DE30',
#    'name': 'German DAX 40 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'CHINA50.ICMARKETS',
#    'symbol': 'CHINA50',
#    'name': 'FTSE China A50 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'China',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'DE40.ICMARKETS',
#    'symbol': 'DE40',
#    'name': 'Germany DAX 40 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'UK100.OANDA',
#    'symbol': 'UK100',
#    'name': 'UK 100',
#    'type': 'cfd',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'OANDA'},
#   {'ticker': 'US2000.PEPPERSTONE',
#    'symbol': 'US2000',
#    'name': 'US 2000 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'VIX.FXPIG',
#    'symbol': 'VIX',
#    'name': 'Volatility Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'FXPIG'},
#   {'ticker': 'VIX.PEPPERSTONE',
#    'symbol': 'VIX',
#    'name': 'US Volatility Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'ASX.FXPIG',
#    'symbol': 'ASX',
#    'name': 'Australian Securities Exchange',
#    'type': 'cfd',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'FXPIG'},
#   {'ticker': 'AU200.OANDA',
#    'symbol': 'AU200',
#    'name': 'Australia 200',
#    'type': 'cfd',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'OANDA'},
#   {'ticker': 'AUS200.ICMARKETS',
#    'symbol': 'AUS200',
#    'name': 'Australian S&P/ASX 200 Index',
#    'type': 'cfd',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'AUS200.PEPPERSTONE',
#    'symbol': 'AUS200',
#    'name': 'Australia 200 Index',
#    'type': 'cfd',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'CA60.ICMARKETS',
#    'symbol': 'CA60',
#    'name': 'Canada 60 Index',
#    'type': 'cfd',
#    'currency': 'CAD',
#    'country': 'Canada',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'CA60.PEPPERSTONE',
#    'symbol': 'CA60',
#    'name': 'Canada 60 Index',
#    'type': 'cfd',
#    'currency': 'CAD',
#    'country': 'Canada',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'CHINAH.ICMARKETS',
#    'symbol': 'CHINAH',
#    'name': 'Hong Kong China H-shares Index',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'CHINAH.PEPPERSTONE',
#    'symbol': 'CHINAH',
#    'name': 'Hong Kong China H-shares Index',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'CN50.OANDA',
#    'symbol': 'CN50',
#    'name': 'China A50',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'China',
#    'exchange': 'OANDA'},
#   {'ticker': 'CN50.PEPPERSTONE',
#    'symbol': 'CN50',
#    'name': 'China 50 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'China',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'DE30.FXPIG',
#    'symbol': 'DE30',
#    'name': 'Dow Jones Germany Titans 30 Index (EUR)',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'FXPIG'},
#   {'ticker': 'DE30.OANDA',
#    'symbol': 'DE30',
#    'name': 'Germany 30',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'OANDA'},
#   {'ticker': 'DJ30.FXPIG',
#    'symbol': 'DJ30',
#    'name': 'DJ30',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'FXPIG'},
#   {'ticker': 'ES35.ICMARKETS',
#    'symbol': 'ES35',
#    'name': 'Spanish IBEX 35 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Spain',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'ES35.PEPPERSTONE',
#    'symbol': 'ES35',
#    'name': 'Spain 35 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Spain',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'EU50.OANDA',
#    'symbol': 'EU50',
#    'name': 'Europe 50',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'OANDA'},
#   {'ticker': 'EURX.PEPPERSTONE',
#    'symbol': 'EURX',
#    'name': 'EUR Currency Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'F40.ICMARKETS',
#    'symbol': 'F40',
#    'name': 'French CAC 40 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'F40.PEPPERSTONE',
#    'symbol': 'F40',
#    'name': 'France 40 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'FR40.OANDA',
#    'symbol': 'FR40',
#    'name': 'France 40',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'OANDA'},
#   {'ticker': 'HK33.OANDA',
#    'symbol': 'HK33',
#    'name': 'Hong Kong 33',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'OANDA'},
#   {'ticker': 'HK50.ICMARKETS',
#    'symbol': 'HK50',
#    'name': 'Chinese Hang Seng 50 Index',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'China',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'HK50.PEPPERSTONE',
#    'symbol': 'HK50',
#    'name': 'Hong Kong 50 Index',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'HKG50.FXPIG',
#    'symbol': 'HKG50',
#    'name': 'Hang Seng 50',
#    'type': 'cfd',
#    'currency': 'HKD',
#    'country': 'China',
#    'exchange': 'FXPIG'},
#   {'ticker': 'IT40.ICMARKETS',
#    'symbol': 'IT40',
#    'name': 'Italian FTSE MIB Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Italy',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'JP225.OANDA',
#    'symbol': 'JP225',
#    'name': 'Japan 225',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'OANDA'},
#   {'ticker': 'JP225.PEPPERSTONE',
#    'symbol': 'JP225',
#    'name': 'Japan 225 Index',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'JP225Y.OANDA',
#    'symbol': 'JP225Y',
#    'name': 'Japan 225 (JPY)',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'OANDA'},
#   {'ticker': 'JPYX.PEPPERSTONE',
#    'symbol': 'JPYX',
#    'name': 'JPY Currency Index',
#    'type': 'cfd',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'MIDDE50.ICMARKETS',
#    'symbol': 'MIDDE50',
#    'name': 'Germany Mid 50 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'MIDDE50.PEPPERSTONE',
#    'symbol': 'MIDDE50',
#    'name': 'Germany Mid 50 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'MIDDE60.ICMARKETS',
#    'symbol': 'MIDDE60',
#    'name': 'Germany Mid 60 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'NETH25.ICMARKETS',
#    'symbol': 'NETH25',
#    'name': 'Netherlands 25 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'NETH25.PEPPERSTONE',
#    'symbol': 'NETH25',
#    'name': 'Netherlands 25 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'NL25.OANDA',
#    'symbol': 'NL25',
#    'name': 'Netherlands 25',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'OANDA'},
#   {'ticker': 'NOR25.ICMARKETS',
#    'symbol': 'NOR25',
#    'name': 'Norway 25 Index',
#    'type': 'cfd',
#    'currency': 'NOK',
#    'country': 'Norway',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'NOR25.PEPPERSTONE',
#    'symbol': 'NOR25',
#    'name': 'Norway 25 Index',
#    'type': 'cfd',
#    'currency': 'NOK',
#    'country': 'Norway',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'SA40.ICMARKETS',
#    'symbol': 'SA40',
#    'name': 'South Africa 40 Index',
#    'type': 'cfd',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'SA40.PEPPERSTONE',
#    'symbol': 'SA40',
#    'name': 'South Africa 40 Index',
#    'type': 'cfd',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'SE30.ICMARKETS',
#    'symbol': 'SE30',
#    'name': 'Sweden 30 Index',
#    'type': 'cfd',
#    'currency': 'SEK',
#    'country': 'Sweden',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'SG30.OANDA',
#    'symbol': 'SG30',
#    'name': 'Singapore 30',
#    'type': 'cfd',
#    'currency': 'SGD',
#    'country': 'Singapore',
#    'exchange': 'OANDA'},
#   {'ticker': 'STOXX50.FXPIG',
#    'symbol': 'STOXX50',
#    'name': 'EURO STOXX 50',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'FXPIG'},
#   {'ticker': 'STOXX50.ICMARKETS',
#    'symbol': 'STOXX50',
#    'name': 'EURO STOXX 50 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'STOXX50.PEPPERSTONE',
#    'symbol': 'STOXX50',
#    'name': 'EU Stocks 50 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'SWI20.ICMARKETS',
#    'symbol': 'SWI20',
#    'name': 'Switzerland 20 Index',
#    'type': 'cfd',
#    'currency': 'CHF',
#    'country': 'Switzerland',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'SWI20.PEPPERSTONE',
#    'symbol': 'SWI20',
#    'name': 'Switzerland 20 Index',
#    'type': 'cfd',
#    'currency': 'CHF',
#    'country': 'Switzerland',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'TECDE30.ICMARKETS',
#    'symbol': 'TECDE30',
#    'name': 'Germany Tech 30 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'TECDE30.PEPPERSTONE',
#    'symbol': 'TECDE30',
#    'name': 'Germany Tech 30 Index',
#    'type': 'cfd',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'UK100.ICMARKETS',
#    'symbol': 'UK100',
#    'name': 'UK 100 Index',
#    'type': 'cfd',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'UK100.PEPPERSTONE',
#    'symbol': 'UK100',
#    'name': 'UK 100 Index',
#    'type': 'cfd',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'UKX.FXPIG',
#    'symbol': 'UKX',
#    'name': 'UK100',
#    'type': 'cfd',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'FXPIG'},
#   {'ticker': 'US2000.ICMARKETS',
#    'symbol': 'US2000',
#    'name': 'USA Russell 2000 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'ICMARKETS'},
#   {'ticker': 'US2000.OANDA',
#    'symbol': 'US2000',
#    'name': 'US Russ 2000',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'OANDA'},
#   {'ticker': 'US30.PEPPERSTONE',
#    'symbol': 'US30',
#    'name': 'US Wall Street 30 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'US500.FXPIG',
#    'symbol': 'US500',
#    'name': 'S&P 500 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'FXPIG'},
#   {'ticker': 'US500.ICMTRADER',
#    'symbol': 'US500',
#    'name': 'S&P 500',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'ICMTRADER'},
#   {'ticker': 'US500.PEPPERSTONE',
#    'symbol': 'US500',
#    'name': 'US 500 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'PEPPERSTONE'},
#   {'ticker': 'USTEC.FXPIG',
#    'symbol': 'USTEC',
#    'name': 'US Tech 100 Index',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'FXPIG'},
#   {'ticker': 'VIX.INDX',
#    'symbol': 'VIX',
#    'name': 'CBOE Volatility Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MOVE.INDX',
#    'symbol': 'MOVE',
#    'name': 'ICE BofAML MOVE Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NIFTY100.INDX',
#    'symbol': 'NIFTY100',
#    'name': 'NIFTY 100',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'DJT.INDX',
#    'symbol': 'DJT',
#    'name': 'Dow Jones Transportation',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'RUT.INDX',
#    'symbol': 'RUT',
#    'name': 'Russell 2000',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SET.INDX',
#    'symbol': 'SET',
#    'name': 'Stock Exchange of Thailand SET Index',
#    'type': 'INDEX',
#    'currency': 'THB',
#    'country': 'Thailand',
#    'exchange': 'INDX'},
#   {'ticker': 'DXY.INDX',
#    'symbol': 'DXY',
#    'name': 'US Dollar Currency Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'FTSE.INDX',
#    'symbol': 'FTSE',
#    'name': 'FTSE 100 Index (UK)',
#    'type': 'INDEX',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'REIT.INDX',
#    'symbol': 'REIT',
#    'name': 'DOW JONES EQUITY ALL REIT TOTAL RETURN INDEX',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'IXIC.INDX',
#    'symbol': 'IXIC',
#    'name': 'NASDAQ Composite',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'N225.INDX',
#    'symbol': 'N225',
#    'name': 'Nikkei 225',
#    'type': 'INDEX',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'INDX'},
#   {'ticker': 'OOI.INDX',
#    'symbol': 'OOI',
#    'name': 'S&P Global 100',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'HSI.INDX',
#    'symbol': 'HSI',
#    'name': 'Hang Seng (Hong Kong)',
#    'type': 'INDEX',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'INDX'},
#   {'ticker': 'GDAXI.INDX',
#    'symbol': 'GDAXI',
#    'name': 'DAX Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'ENDOW.INDX',
#    'symbol': 'ENDOW',
#    'name': 'Endowment Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'FCHI.INDX',
#    'symbol': 'FCHI',
#    'name': 'CAC 40',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'PUT.INDX',
#    'symbol': 'PUT',
#    'name': 'CBOE S&P 500 PutWrite Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW06.INDX',
#    'symbol': 'AW06',
#    'name': 'ASIA PACIFIC',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'US500.INDX',
#    'symbol': 'US500',
#    'name': 'S&P 500 Futures',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'STOXX.INDX',
#    'symbol': 'STOXX',
#    'name': 'Stoxx Europe 600',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'TOPX.INDX',
#    'symbol': 'TOPX',
#    'name': 'TOPIX',
#    'type': 'INDEX',
#    'currency': 'JPY',
#    'country': 'Japan',
#    'exchange': 'INDX'},
#   {'ticker': 'NYA.INDX',
#    'symbol': 'NYA',
#    'name': 'NYSE Composite',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'STOXX50E.INDX',
#    'symbol': 'STOXX50E',
#    'name': 'Euro Stoxx 50',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'US10Y.INDX',
#    'symbol': 'US10Y',
#    'name': 'U.S. 10 Year Treasury',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MID.INDX',
#    'symbol': 'MID',
#    'name': 'S&P Midcap 400',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'XAG.INDX',
#    'symbol': 'XAG',
#    'name': 'Stlmt ID PHLX Gold/Silver Sector',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'RUI.INDX',
#    'symbol': 'RUI',
#    'name': 'RUSSELL 1000 INDEX',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NSEI.INDX',
#    'symbol': 'NSEI',
#    'name': 'NIFTY 50',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'XAU.INDX',
#    'symbol': 'XAU',
#    'name': 'Philadelphia Gold/Silver',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'IBEX.INDX',
#    'symbol': 'IBEX',
#    'name': 'IBEX 35 Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Spain',
#    'exchange': 'INDX'},
#   {'ticker': 'KS11.INDX',
#    'symbol': 'KS11',
#    'name': 'KOSPI',
#    'type': 'INDEX',
#    'currency': 'KRW',
#    'country': 'Korea',
#    'exchange': 'INDX'},
#   {'ticker': 'BVSP.INDX',
#    'symbol': 'BVSP',
#    'name': 'BOVESPA Index',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'INDX'},
#   {'ticker': 'N100.INDX',
#    'symbol': 'N100',
#    'name': 'EuroNext 100',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'AXJO.INDX',
#    'symbol': 'AXJO',
#    'name': 'S&P/ASX 200',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'SSEC.INDX',
#    'symbol': 'SSEC',
#    'name': 'Shanghai Composite',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'INDX'},
#   {'ticker': 'NSEBANK.INDX',
#    'symbol': 'NSEBANK',
#    'name': 'NIFTY BANK',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'SSMI.INDX',
#    'symbol': 'SSMI',
#    'name': 'Swiss Market Index',
#    'type': 'INDEX',
#    'currency': 'CHF',
#    'country': 'Switzerland',
#    'exchange': 'INDX'},
#   {'ticker': 'NIFVIX.INDX',
#    'symbol': 'NIFVIX',
#    'name': 'INDIA VIX',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'US2Y.INDX',
#    'symbol': 'US2Y',
#    'name': 'U.S. 2 Year Treasury',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMCL.INDX',
#    'symbol': 'BCOMCL',
#    'name': 'Bloomberg WTI Crude Oil',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'XU100.INDX',
#    'symbol': 'XU100',
#    'name': 'BIST 100',
#    'type': 'INDEX',
#    'currency': 'TRY',
#    'country': 'Turkey',
#    'exchange': 'INDX'},
#   {'ticker': 'MSCIWORLD.INDX',
#    'symbol': 'MSCIWORLD',
#    'name': 'MSCI World',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MAHA.INDX',
#    'symbol': 'MAHA',
#    'name': '52-Week Highs AMEX',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'FTMC.INDX',
#    'symbol': 'FTMC',
#    'name': 'FTSE 250',
#    'type': 'INDEX',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'RTSI.INDX',
#    'symbol': 'RTSI',
#    'name': 'RTSI Index (Russia)',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Russia',
#    'exchange': 'INDX'},
#   {'ticker': 'KSE100.INDX',
#    'symbol': 'KSE100',
#    'name': 'Karachi 100',
#    'type': 'INDEX',
#    'currency': 'PKR',
#    'country': 'Pakistan',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMCO.INDX',
#    'symbol': 'BCOMCO',
#    'name': 'Bloomberg Brent Crude',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'XSP.INDX',
#    'symbol': 'XSP',
#    'name': 'S&P 500 MINI SPX OPTIONS INDEX',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'HSTECH.INDX',
#    'symbol': 'HSTECH',
#    'name': 'Hang Seng TECH',
#    'type': 'INDEX',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'INDX'},
#   {'ticker': 'SX5E.INDX',
#    'symbol': 'SX5E',
#    'name': 'Euro Stoxx 50',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'AEX.INDX',
#    'symbol': 'AEX',
#    'name': 'AEX Amsterdam Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMSBTR.INDX',
#    'symbol': 'BCOMSBTR',
#    'name': 'Bloomberg Sugar Total Return',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DJUS.INDX',
#    'symbol': 'DJUS',
#    'name': 'Dow Jones US',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'GSPTSE.INDX',
#    'symbol': 'GSPTSE',
#    'name': 'S&P TSX Composite Index (Canada)',
#    'type': 'INDEX',
#    'currency': 'CAD',
#    'country': 'Canada',
#    'exchange': 'INDX'},
#   {'ticker': 'IMOEX.INDX',
#    'symbol': 'IMOEX',
#    'name': 'MOEX Russia',
#    'type': 'INDEX',
#    'currency': 'RUB',
#    'country': 'Russia',
#    'exchange': 'INDX'},
#   {'ticker': 'JTOPI.INDX',
#    'symbol': 'JTOPI',
#    'name': 'FTSE/JSE Top 40 Index',
#    'type': 'INDEX',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'INDX'},
#   {'ticker': 'US5Y.INDX',
#    'symbol': 'US5Y',
#    'name': 'U.S. 5 Year Treasury',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'BUX.INDX',
#    'symbol': 'BUX',
#    'name': 'Budapest SE',
#    'type': 'INDEX',
#    'currency': 'HUF',
#    'country': 'Hungary',
#    'exchange': 'INDX'},
#   {'ticker': 'TICK.INDX',
#    'symbol': 'TICK',
#    'name': 'NYSE Tick Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'BSESN.INDX',
#    'symbol': 'BSESN',
#    'name': 'BSE Sensex 30',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'CNXIT.INDX',
#    'symbol': 'CNXIT',
#    'name': 'NIFTY IT',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'CNXPHARMA.INDX',
#    'symbol': 'CNXPHARMA',
#    'name': 'NIFTY PHARMA',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'EVZ.INDX',
#    'symbol': 'EVZ',
#    'name': 'CBOE Euro Currency Volatility',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'PSEI.INDX',
#    'symbol': 'PSEI',
#    'name': 'THE PHILIPPINE STOCK EXC PSEI INDEX',
#    'type': 'INDEX',
#    'currency': 'PHP',
#    'country': 'Philippines',
#    'exchange': 'INDX'},
#   {'ticker': 'TNX.INDX',
#    'symbol': 'TNX',
#    'name': 'Cboe Interest Rate 10 Year T Note',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'US30Y.INDX',
#    'symbol': 'US30Y',
#    'name': 'U.S. 30 Year Treasury',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'VVIX.INDX',
#    'symbol': 'VVIX',
#    'name': 'CBOE Vix Volatility',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'ACWI.INDX',
#    'symbol': 'ACWI',
#    'name': 'MSCI International ACWI Net Index US',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'PAX.INDX',
#    'symbol': 'PAX',
#    'name': 'CAC All Shares Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMNG.INDX',
#    'symbol': 'BCOMNG',
#    'name': 'Bloomberg Natural Gas',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DJCI.INDX',
#    'symbol': 'DJCI',
#    'name': 'Dow Jones Commodity',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DJUSEN.INDX',
#    'symbol': 'DJUSEN',
#    'name': 'Dow Jones Oil & Gas',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NZ50.INDX',
#    'symbol': 'NZ50',
#    'name': 'S&P/NZX 50 INDEX GROSS',
#    'type': 'INDEX',
#    'currency': 'NZD',
#    'country': 'New Zealand',
#    'exchange': 'INDX'},
#   {'ticker': 'SP100.INDX',
#    'symbol': 'SP100',
#    'name': 'S&P 100 Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SPMIB.INDX',
#    'symbol': 'SPMIB',
#    'name': 'FTSE MIB',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Italy',
#    'exchange': 'INDX'},
#   {'ticker': 'SPNY.INDX',
#    'symbol': 'SPNY',
#    'name': 'S&P 500 Energy',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SSE180.INDX',
#    'symbol': 'SSE180',
#    'name': 'SSE 180 Index',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'INDX'},
#   {'ticker': 'UKX.INDX',
#    'symbol': 'UKX',
#    'name': 'FTSE 100 Index (UK)',
#    'type': 'INDEX',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'US1Y.INDX',
#    'symbol': 'US1Y',
#    'name': 'U.S. 1 Year Treasury Bill',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW10.INDX',
#    'symbol': 'AW10',
#    'name': 'GREATER CHINA',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'CSI300.INDX',
#    'symbol': 'CSI300',
#    'name': 'Shanghai Shenzhen CSI 300',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'INDX'},
#   {'ticker': 'INDX.SA',
#    'symbol': 'INDX',
#    'name': 'BOVESPA INDUSTRIAL SECTOR INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'KOSDAQ.INDX',
#    'symbol': 'KOSDAQ',
#    'name': 'Kosdaq Composite Index',
#    'type': 'INDEX',
#    'currency': 'KRW',
#    'country': 'Korea',
#    'exchange': 'INDX'},
#   {'ticker': 'KSI.INDX',
#    'symbol': 'KSI',
#    'name': 'Karachi All Share',
#    'type': 'INDEX',
#    'currency': 'PKR',
#    'country': 'Pakistan',
#    'exchange': 'INDX'},
#   {'ticker': 'MIIN00000PIN.INDX',
#    'symbol': 'MIIN00000PIN',
#    'name': 'MSCI India',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'OMX.INDX',
#    'symbol': 'OMX',
#    'name': 'OMXS 30 Index',
#    'type': 'INDEX',
#    'currency': 'SEK',
#    'country': 'Sweden',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMSI.INDX',
#    'symbol': 'BCOMSI',
#    'name': 'Bloomberg Silver',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'CNXCONSUM.INDX',
#    'symbol': 'CNXCONSUM',
#    'name': 'NIFTY CONSUMPTION',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'CNXFIN.INDX',
#    'symbol': 'CNXFIN',
#    'name': 'NIFTY FINANCIAL SERVICES',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'CNXFMCG.INDX',
#    'symbol': 'CNXFMCG',
#    'name': 'NIFTY FMCG',
#    'type': 'INDEX',
#    'currency': 'INR',
#    'country': 'India',
#    'exchange': 'INDX'},
#   {'ticker': 'FTAS.INDX',
#    'symbol': 'FTAS',
#    'name': 'UK FTSE All Share',
#    'type': 'INDEX',
#    'currency': 'GBP',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'JKSE.INDX',
#    'symbol': 'JKSE',
#    'name': 'Jakarta Stock Exchange Composite Index',
#    'type': 'INDEX',
#    'currency': 'IDR',
#    'country': 'Indonesia',
#    'exchange': 'INDX'},
#   {'ticker': 'MERV.INDX',
#    'symbol': 'MERV',
#    'name': 'S&P Merval',
#    'type': 'INDEX',
#    'currency': 'ARS',
#    'country': 'Argentina',
#    'exchange': 'INDX'},
#   {'ticker': 'MXX.INDX',
#    'symbol': 'MXX',
#    'name': 'IPC MEXICO',
#    'type': 'INDEX',
#    'currency': 'MXN',
#    'country': 'Mexico',
#    'exchange': 'INDX'},
#   {'ticker': 'NQ.INDX',
#    'symbol': 'NQ',
#    'name': 'E-Mini Nasdaq 100',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'OBX.INDX',
#    'symbol': 'OBX',
#    'name': 'Oslo OBX Stock Index',
#    'type': 'INDEX',
#    'currency': 'NOK',
#    'country': 'Norway',
#    'exchange': 'INDX'},
#   {'ticker': 'OEX.INDX',
#    'symbol': 'OEX',
#    'name': 'S&P 100',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'OMXC20.INDX',
#    'symbol': 'OMXC20',
#    'name': 'OMX Copenhagen 20  Index',
#    'type': 'INDEX',
#    'currency': 'DKK',
#    'country': 'Denmark',
#    'exchange': 'INDX'},
#   {'ticker': 'SP400.INDX',
#    'symbol': 'SP400',
#    'name': 'S&P 400 Midcap',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SP500-151010.INDX',
#    'symbol': 'SP500-151010',
#    'name': 'S&P 500 Chemicals',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SP500NTR.INDX',
#    'symbol': 'SP500NTR',
#    'name': 'S&P 500 Net Total Return',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SP500TR.INDX',
#    'symbol': 'SP500TR',
#    'name': 'S&P 500 TR (Total Return)',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SPTSX60.INDX',
#    'symbol': 'SPTSX60',
#    'name': 'S&P/TSX 60 INDEX',
#    'type': 'INDEX',
#    'currency': 'CAD',
#    'country': 'Canada',
#    'exchange': 'INDX'},
#   {'ticker': 'TECDAX.INDX',
#    'symbol': 'TECDAX',
#    'name': 'TecDAX',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'TTNI.INDX',
#    'symbol': 'TTNI',
#    'name': 'Saudi Arabia Transportation',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TYX.INDX',
#    'symbol': 'TYX',
#    'name': 'CBOE Treasury Yield 30 Years  Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'US3M.INDX',
#    'symbol': 'US3M',
#    'name': 'U.S. 3 Month Treasury Bill',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'VXN.INDX',
#    'symbol': 'VXN',
#    'name': 'CBOE NASDAQ 100 Volatility',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'WIG.INDX',
#    'symbol': 'WIG',
#    'name': 'WSE WIG INDEX',
#    'type': 'INDEX',
#    'currency': 'PLN',
#    'country': 'Poland',
#    'exchange': 'INDX'},
#   {'ticker': 'XBOV.SA',
#    'symbol': 'XBOV',
#    'name': 'Caixa ETF Ibovespa Index',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'XOI.INDX',
#    'symbol': 'XOI',
#    'name': 'ARCA Oil',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'US30.FXCM',
#    'symbol': 'US30',
#    'name': 'US30',
#    'type': 'cfd',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'FXCM'},
#   {'ticker': 'CFANG.STU',
#    'symbol': 'CFANG',
#    'name': 'China Fang Index PR',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'STU'},
#   {'ticker': 'CFANGNTR.STU',
#    'symbol': 'CFANGNTR',
#    'name': 'China Fang Index NTR',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'STU'},
#   {'ticker': 'DE000SLA3UE7.STU',
#    'symbol': 'DE000SLA3UE7',
#    'name': 'Prime Cyber Defense Index (Gross Return) (USD)',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'STU'},
#   {'ticker': 'HARVESTN.STU',
#    'symbol': 'HARVESTN',
#    'name': 'PR ALT HARV NTR',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'STU'},
#   {'ticker': 'HARVESTP.STU',
#    'symbol': 'HARVESTP',
#    'name': 'PR ALT HARV PR INDEX',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'STU'},
#   {'ticker': 'SPI20.SW',
#    'symbol': 'SPI20',
#    'name': 'Swiss Performance Index SPI 20',
#    'type': 'INDEX',
#    'currency': 'CHF',
#    'country': 'Switzerland',
#    'exchange': 'SW'},
#   {'ticker': 'DKIDKIX.CO',
#    'symbol': 'DKIDKIX',
#    'name': 'Danske Invest Danmark Indeks',
#    'type': 'INDEX',
#    'currency': 'DKK',
#    'country': 'Denmark',
#    'exchange': 'CO'},
#   {'ticker': 'CSHK100.HK',
#    'symbol': 'CSHK100',
#    'name': 'CSI HKG 100 INDEX',
#    'type': 'INDEX',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'HK'},
#   {'ticker': 'HKL.HK',
#    'symbol': 'HKL',
#    'name': 'S&P/HKEX LARGECAP INDEX',
#    'type': 'INDEX',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'HK'},
#   {'ticker': 'HSMBI.HK',
#    'symbol': 'HSMBI',
#    'name': 'HANG SENG MAINLAND BANKS INDEX',
#    'type': 'INDEX',
#    'currency': 'HKD',
#    'country': 'Hong Kong',
#    'exchange': 'HK'},
#   {'ticker': 'FSTAS.SG',
#    'symbol': 'FSTAS',
#    'name': 'FTSE ST All-Share Index',
#    'type': 'INDEX',
#    'currency': 'SGD',
#    'country': 'Singapore',
#    'exchange': 'SG'},
#   {'ticker': '000001.SHG',
#    'symbol': '000001',
#    'name': 'SSE Composite Index',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'SHG'},
#   {'ticker': '000300.SHG',
#    'symbol': '000300',
#    'name': 'Tebon Deli Money Market Fund A',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'SHG'},
#   {'ticker': 'JALSH.JSE',
#    'symbol': 'JALSH',
#    'name': 'JSE FTSE ALL SHARE INDEX',
#    'type': 'INDEX',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'JSE'},
#   {'ticker': 'HNX30.VN',
#    'symbol': 'HNX30',
#    'name': 'HNX30',
#    'type': 'cfd',
#    'currency': None,
#    'country': None,
#    'exchange': 'VN'},
#   {'ticker': 'HNX.VN',
#    'symbol': 'HNX',
#    'name': 'HNX',
#    'type': 'cfd',
#    'currency': None,
#    'country': None,
#    'exchange': 'VN'},
#   {'ticker': 'VN30.VN',
#    'symbol': 'VN30',
#    'name': 'VN30',
#    'type': 'cfd',
#    'currency': None,
#    'country': None,
#    'exchange': 'VN'},
#   {'ticker': 'VNINDEX.VN',
#    'symbol': 'VNINDEX',
#    'name': 'VNINDEX',
#    'type': 'cfd',
#    'currency': None,
#    'country': None,
#    'exchange': 'VN'},
#   {'ticker': 'UPCOM.VN',
#    'symbol': 'UPCOM',
#    'name': 'UPCOM',
#    'type': 'cfd',
#    'currency': None,
#    'country': None,
#    'exchange': 'VN'},
#   {'ticker': 'BDRX.SA',
#    'symbol': 'BDRX',
#    'name': 'INDICE DE BDR NAO PATR GLOBAL INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'IBRA.SA',
#    'symbol': 'IBRA',
#    'name': 'BRAZIL BROAD BASED INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'IBXX.SA',
#    'symbol': 'IBXX',
#    'name': 'SAO PAULO SE IBX INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'ICO2.SA',
#    'symbol': 'ICO2',
#    'name': 'CARBON EFFICIENT INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'IDIV.SA',
#    'symbol': 'IDIV',
#    'name': 'DIVIDEND INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'IFIX.SA',
#    'symbol': 'IFIX',
#    'name': 'INDICE DE FII INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'IMOB.SA',
#    'symbol': 'IMOB',
#    'name': 'REAL ESTATE INDEX IMOB',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'ISEE.SA',
#    'symbol': 'ISEE',
#    'name': 'CORPORATE SUSTAINABILITY INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'MLCX.SA',
#    'symbol': 'MLCX',
#    'name': 'BMF BOVESPA MIDLARGECAP INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': 'SMLL.SA',
#    'symbol': 'SMLL',
#    'name': 'BMF BOVESPA SMALL CAP INDEX',
#    'type': 'INDEX',
#    'currency': 'BRL',
#    'country': 'Brazil',
#    'exchange': 'SA'},
#   {'ticker': '000906.INDX',
#    'symbol': '000906',
#    'name': 'China Securities 800',
#    'type': 'INDEX',
#    'currency': 'CNY',
#    'country': 'China',
#    'exchange': 'INDX'},
#   {'ticker': '0O7N.INDX',
#    'symbol': '0O7N',
#    'name': 'Scale All Share GR EUR',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': '3LHE.INDX',
#    'symbol': '3LHE',
#    'name': 'ESTX 50 Corporate Bond TR',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Greece',
#    'exchange': 'INDX'},
#   {'ticker': '5SP2550.INDX',
#    'symbol': '5SP2550',
#    'name': 'S&P 500 Retailing (Industry Group)',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': '990100.INDX',
#    'symbol': '990100',
#    'name': 'MSCI International World Index Price',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AFLI.INDX',
#    'symbol': 'AFLI',
#    'name': 'S&P/ASX 50',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AMX.INDX',
#    'symbol': 'AMX',
#    'name': 'AMX-Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'INDX'},
#   {'ticker': 'AORD.INDX',
#    'symbol': 'AORD',
#    'name': 'Australia All Ordinaries',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'ASCX.INDX',
#    'symbol': 'ASCX',
#    'name': 'AMS Small Cap',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Netherlands',
#    'exchange': 'INDX'},
#   {'ticker': 'ASX.INDX',
#    'symbol': 'ASX',
#    'name': 'FTSE All Share Index',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'ATF.INDX',
#    'symbol': 'ATF',
#    'name': 'FTSE/ATHEX Large Cap',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'ATLI.INDX',
#    'symbol': 'ATLI',
#    'name': 'S&P/ASX 20',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'ATOI.INDX',
#    'symbol': 'ATOI',
#    'name': 'S&P/ASX 100',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'ATX.INDX',
#    'symbol': 'ATX',
#    'name': 'Austrian Traded Index in EUR',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Austria',
#    'exchange': 'INDX'},
#   {'ticker': 'ATXPRIME.INDX',
#    'symbol': 'ATXPRIME',
#    'name': 'ATX Prime',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW01.INDX',
#    'symbol': 'AW01',
#    'name': 'FTSE All World',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW02.INDX',
#    'symbol': 'AW02',
#    'name': 'FTSE ALL-WORLD EX USA',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW03.INDX',
#    'symbol': 'AW03',
#    'name': 'ALL-WORLD EX UK',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW04.INDX',
#    'symbol': 'AW04',
#    'name': 'FTSE All-World ex Japan',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW05.INDX',
#    'symbol': 'AW05',
#    'name': 'ALL-WORLD EX S A',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW07.INDX',
#    'symbol': 'AW07',
#    'name': 'FTSE Asia Pacific ex Japan',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW08.INDX',
#    'symbol': 'AW08',
#    'name': 'ASIA PAC X J I P',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW09.INDX',
#    'symbol': 'AW09',
#    'name': 'ASIA PAC X JIPAN',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW11.INDX',
#    'symbol': 'AW11',
#    'name': 'FTSE All World Europe Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW12.INDX',
#    'symbol': 'AW12',
#    'name': 'EUROPE EX UK',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW13.INDX',
#    'symbol': 'AW13',
#    'name': 'EURO EX EUROBLOC',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AW14.INDX',
#    'symbol': 'AW14',
#    'name': 'EUROBLOC',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'AXDJ.INDX',
#    'symbol': 'AXDJ',
#    'name': 'S&P/ASX 200 Consumer Discretionary',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXEJ.INDX',
#    'symbol': 'AXEJ',
#    'name': 'S&P/ASX 200 Energy',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXFJ.INDX',
#    'symbol': 'AXFJ',
#    'name': 'S&P/ASX 200 Financials',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXGD.INDX',
#    'symbol': 'AXGD',
#    'name': 'ASX All Ordinaries Gold',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXHJ.INDX',
#    'symbol': 'AXHJ',
#    'name': 'S&P/ASX 200 Health Care',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXIJ.INDX',
#    'symbol': 'AXIJ',
#    'name': 'S&P/ASX 200 Information Technology',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXIKD.INDX',
#    'symbol': 'AXIKD',
#    'name': 'S&P/ASX 300 Information Technology',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXJOA.INDX',
#    'symbol': 'AXJOA',
#    'name': 'S&P/ASX 200 Accumulated',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXKO.INDX',
#    'symbol': 'AXKO',
#    'name': 'S&P/ASX 300',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXMD.INDX',
#    'symbol': 'AXMD',
#    'name': 'S&P/ASX Midcap 50',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXMEJD.INDX',
#    'symbol': 'AXMEJD',
#    'name': 'S&P/ASX 200 Media',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXMEKD.INDX',
#    'symbol': 'AXMEKD',
#    'name': 'S&P/ASX 300 Media',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXMJ.INDX',
#    'symbol': 'AXMJ',
#    'name': 'S&P/ASX 200 Materials',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXMM.INDX',
#    'symbol': 'AXMM',
#    'name': 'S&P/ASX 300 Metals & Mining',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXNJ.INDX',
#    'symbol': 'AXNJ',
#    'name': 'S&P/ASX 200 Industrials',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXPJ.INDX',
#    'symbol': 'AXPJ',
#    'name': 'S&P/ASX 200 REIT',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXSJ.INDX',
#    'symbol': 'AXSJ',
#    'name': 'S&P/ASX 200 Consumer Staples',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXSO.INDX',
#    'symbol': 'AXSO',
#    'name': 'ASX Small Ordinaries',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXTJ.INDX',
#    'symbol': 'AXTJ',
#    'name': 'S&P/ASX 200 Telecommunication Services',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXTKD.INDX',
#    'symbol': 'AXTKD',
#    'name': 'S&P/ASX 300 Telecommunication Services',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXTX.INDX',
#    'symbol': 'AXTX',
#    'name': 'S&P/ASX All Technology',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXUJ.INDX',
#    'symbol': 'AXUJ',
#    'name': 'S&P/ASX 200 Utilities',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'AXXJ.INDX',
#    'symbol': 'AXXJ',
#    'name': 'S&P/ASX Financials ex REIT',
#    'type': 'INDEX',
#    'currency': 'AUD',
#    'country': 'Australia',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMAG.INDX',
#    'symbol': 'BCOMAG',
#    'name': 'Bloomberg Agriculture',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'BCOMAGTR.INDX',
#    'symbol': 'BCOMAGTR',
#    'name': 'Bloomberg Agriculture Total Return',
# ...
#    'country': 'Vietnam',
#    'exchange': 'INDX'},
#   {'ticker': 'VNI30.INDX',
#    'symbol': 'VNI30',
#    'name': 'VN 30',
#    'type': 'INDEX',
#    'currency': 'VND',
#    'country': 'Vietnam',
#    'exchange': 'INDX'},
#   {'ticker': 'VNIAS.INDX',
#    'symbol': 'VNIAS',
#    'name': 'VN All Shares',
#    'type': 'INDEX',
#    'currency': 'VND',
#    'country': 'Vietnam',
#    'exchange': 'INDX'},
#   {'ticker': 'VNIMC.INDX',
#    'symbol': 'VNIMC',
#    'name': 'VN Mid Cap',
#    'type': 'INDEX',
#    'currency': 'VND',
#    'country': 'Vietnam',
#    'exchange': 'INDX'},
#   {'ticker': 'VNISC.INDX',
#    'symbol': 'VNISC',
#    'name': 'VN Small Cap',
#    'type': 'INDEX',
#    'currency': 'VND',
#    'country': 'Vietnam',
#    'exchange': 'INDX'},
#   {'ticker': 'MSCIUSAN.INDX',
#    'symbol': 'MSCIUSAN',
#    'name': 'MSCI US Net USD',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'IBEXTR.INDX',
#    'symbol': 'IBEXTR',
#    'name': 'IBEX Total Return',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Spain',
#    'exchange': 'INDX'},
#   {'ticker': 'CACLG.INDX',
#    'symbol': 'CACLG',
#    'name': 'CAC Large 60',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'CACMD.INDX',
#    'symbol': 'CACMD',
#    'name': 'CAC Mid 60',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRBM.INDX',
#    'symbol': 'FRBM',
#    'name': 'CAC Basic Materials',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRCS.INDX',
#    'symbol': 'FRCS',
#    'name': 'CAC Consumer Service',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRFIN.INDX',
#    'symbol': 'FRFIN',
#    'name': 'CAC Financials',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRHC.INDX',
#    'symbol': 'FRHC',
#    'name': 'CAC Health Care',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRIN.INDX',
#    'symbol': 'FRIN',
#    'name': 'CAC Industrials',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRTEC.INDX',
#    'symbol': 'FRTEC',
#    'name': 'CAC Technology',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'FRTEL.INDX',
#    'symbol': 'FRTEL',
#    'name': 'CAC TELECOMMUNICATIONS',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'France',
#    'exchange': 'INDX'},
#   {'ticker': 'MMFI.INDX',
#    'symbol': 'MMFI',
#    'name': 'Percent of stocks above 50 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MMTH.INDX',
#    'symbol': 'MMTH',
#    'name': 'Percent of stocks above 200 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MMTW.INDX',
#    'symbol': 'MMTW',
#    'name': 'Percent of stocks above 20 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NDFI.INDX',
#    'symbol': 'NDFI',
#    'name': 'Percent of Nasdaq stocks above 50 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NDTH.INDX',
#    'symbol': 'NDTH',
#    'name': 'Percent of Nasdaq stocks above 200 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NDTW.INDX',
#    'symbol': 'NDTW',
#    'name': 'Percent of Nasdaq stocks above 20 day average',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'ADVA.INDX',
#    'symbol': 'ADVA',
#    'name': 'AMEX Advancing Stocks',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'ADVN.INDX',
#    'symbol': 'ADVN',
#    'name': 'NYSE Advancing Stocks',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'ADVQ.INDX',
#    'symbol': 'ADVQ',
#    'name': 'NASD Advancing Stocks',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DECA.INDX',
#    'symbol': 'DECA',
#    'name': 'AMEX Declining Stocks',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DECN.INDX',
#    'symbol': 'DECN',
#    'name': 'NYSE Declining Stocks',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DECQ.INDX',
#    'symbol': 'DECQ',
#    'name': 'NASD Declining Stocks',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'HIGA.INDX',
#    'symbol': 'HIGA',
#    'name': 'AMEX New Highs',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'HIGN.INDX',
#    'symbol': 'HIGN',
#    'name': 'NYSE New Highs',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'HIGQ.INDX',
#    'symbol': 'HIGQ',
#    'name': 'NASD New Highs',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'LOWA.INDX',
#    'symbol': 'LOWA',
#    'name': 'AMEX New Lows',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'LOWN.INDX',
#    'symbol': 'LOWN',
#    'name': 'NYSE New Lows',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'LOWQ.INDX',
#    'symbol': 'LOWQ',
#    'name': 'NASD New Lows',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MAHN.INDX',
#    'symbol': 'MAHN',
#    'name': '52-Week Highs NYSE',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MAHQ.INDX',
#    'symbol': 'MAHQ',
#    'name': '52-Week Highs Nasdaq',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MALA.INDX',
#    'symbol': 'MALA',
#    'name': '52-Week Lows AMEX',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MALN.INDX',
#    'symbol': 'MALN',
#    'name': '52-Week Lows NYSE',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MALQ.INDX',
#    'symbol': 'MALQ',
#    'name': '52-Week Lows Nasdaq',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'TASI.SR',
#    'symbol': 'TASI',
#    'name': 'Tadawul All Shares Index',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'SR'},
#   {'ticker': 'SPGSCLTR.INDX',
#    'symbol': 'SPGSCLTR',
#    'name': 'S&P GSCI Crude Oil Index Total',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'J433TR.INDX',
#    'symbol': 'J433TR',
#    'name': 'FTSE/JSE Capped Shareholder Weighted TR',
#    'type': 'INDEX',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'INDX'},
#   {'ticker': 'IXEGD50.INDX',
#    'symbol': 'IXEGD50',
#    'name': 'iSTOXX® Europe 600 Energy ex Coal GR Decrement 50',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'DE30.INDX',
#    'symbol': 'DE30',
#    'name': 'Dow Jones Germany Titans 30 Index',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'DE30D.INDX',
#    'symbol': 'DE30D',
#    'name': 'Dow Jones Germany Titans 30 USD',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'DE30DT.INDX',
#    'symbol': 'DE30DT',
#    'name': 'Dow Jones Germany Titans 30 Total Return US',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'DE30TR.INDX',
#    'symbol': 'DE30TR',
#    'name': 'DJ Germany 30 TR',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Germany',
#    'exchange': 'INDX'},
#   {'ticker': 'LCXP.INDX',
#    'symbol': 'LCXP',
#    'name': 'STOXX Europe Large 200 EUR Price',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'LCXR.INDX',
#    'symbol': 'LCXR',
#    'name': 'STOXX Europe Large 200 Net Return',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'MCXP.INDX',
#    'symbol': 'MCXP',
#    'name': 'STOXX Europe Mid 200 EUR Price',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'MCXR.INDX',
#    'symbol': 'MCXR',
#    'name': 'STOXX Europe Mid 200 EUR Net Return',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'SCXP.INDX',
#    'symbol': 'SCXP',
#    'name': 'STOXX Europe Small 200 EUR Price',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'SCXR.INDX',
#    'symbol': 'SCXR',
#    'name': 'STOXX Europe Small 200 EUR Net Return',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'Europe',
#    'exchange': 'INDX'},
#   {'ticker': 'JNIV.INDX',
#    'symbol': 'JNIV',
#    'name': 'Nikkei Volatility',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'Japan',
#    'exchange': 'INDX'},
#   {'ticker': 'NOMUC.INDX',
#    'symbol': 'NOMUC',
#    'name': 'NOMU Parallel Market Capped',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'AMZ.INDX',
#    'symbol': 'AMZ',
#    'name': 'Alerian MLP Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'DWGROT.INDX',
#    'symbol': 'DWGROT',
#    'name': 'Dow Jones U.S. Growth Total Stock Market',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MIWU00000GUS.INDX',
#    'symbol': 'MIWU00000GUS',
#    'name': 'MSCI International ACWI ex USA Gross',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'MIWU00000NUS.INDX',
#    'symbol': 'MIWU00000NUS',
#    'name': 'MSCI International ACWI ex USA Net',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'NRU.INDX',
#    'symbol': 'NRU',
#    'name': 'S&P Global Natural Resources Index',
#    'type': 'INDEX',
#    'currency': 'USD',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'SPGNRET.INDX',
#    'symbol': 'SPGNRET',
#    'name': 'S&P Global Natural Resources Index Equal Weight',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United States',
#    'exchange': 'INDX'},
#   {'ticker': 'TBNI.INDX',
#    'symbol': 'TBNI',
#    'name': 'Saudi Arabia Banks Index',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TCGI.INDX',
#    'symbol': 'TCGI',
#    'name': 'Capital Goods',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TCPIC.INDX',
#    'symbol': 'TCPIC',
#    'name': 'Commercial & Professional Services',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TCSI.INDX',
#    'symbol': 'TCSI',
#    'name': 'Saudi Arabia Consumer Services Index',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TDAI.INDX',
#    'symbol': 'TDAI',
#    'name': 'Consumer Durables & Apparel',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TDFI.INDX',
#    'symbol': 'TDFI',
#    'name': 'Saudi Arabia Diversified Financials',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TENI.INDX',
#    'symbol': 'TENI',
#    'name': 'Saudi Arabia Energy',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TFBI.INDX',
#    'symbol': 'TFBI',
#    'name': 'Saudi Arabia Food and Beverages',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TFSI.INDX',
#    'symbol': 'TFSI',
#    'name': 'Saudi Arabia Food & Staples Retailing',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'THEI.INDX',
#    'symbol': 'THEI',
#    'name': 'Saudi Arabia Health Care Equipment & Services',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TISII.INDX',
#    'symbol': 'TISII',
#    'name': 'Saudi Arabia Insurance',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TMDI.INDX',
#    'symbol': 'TMDI',
#    'name': 'Media\xa0',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TMTI.INDX',
#    'symbol': 'TMTI',
#    'name': 'Saudi Arabia Materials\xa0Index',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TPBI.INDX',
#    'symbol': 'TPBI',
#    'name': 'Pharma Biotech & Life Science',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TRLI.INDX',
#    'symbol': 'TRLI',
#    'name': 'Saudi Arabia Retailing',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TTSI.INDX',
#    'symbol': 'TTSI',
#    'name': 'Saudi Arabia Telecommunication Services',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'TUTI.INDX',
#    'symbol': 'TUTI',
#    'name': 'Saudi Arabia Utilities',
#    'type': 'INDEX',
#    'currency': 'SAR',
#    'country': 'Saudi Arabia',
#    'exchange': 'INDX'},
#   {'ticker': 'JALSH.INDX',
#    'symbol': 'JALSH',
#    'name': 'JSE FTSE ALL SHARE INDEX',
#    'type': 'INDEX',
#    'currency': 'ZAR',
#    'country': 'South Africa',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK100N.INDX',
#    'symbol': 'BUK100N',
#    'name': 'Cboe UK 100',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK100P.INDX',
#    'symbol': 'BUK100P',
#    'name': 'Cboe UK 100',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK250N.INDX',
#    'symbol': 'BUK250N',
#    'name': 'Cboe UK 250',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK250P.INDX',
#    'symbol': 'BUK250P',
#    'name': 'Cboe UK 250',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK350N.INDX',
#    'symbol': 'BUK350N',
#    'name': 'Cboe UK 350',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUK350P.INDX',
#    'symbol': 'BUK350P',
#    'name': 'Cboe UK 350',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUKACN.INDX',
#    'symbol': 'BUKACN',
#    'name': 'Cboe UK All Companies',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUKBISN.INDX',
#    'symbol': 'BUKBISN',
#    'name': 'Cboe UK Banking and Investment Services',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'},
#   {'ticker': 'BUKBUS.INDX',
#    'symbol': 'BUKBUS',
#    'name': 'Cboe UK Business Services Sector',
#    'type': 'INDEX',
#    'currency': 'EUR',
#    'country': 'United Kingdom',
#    'exchange': 'INDX'}],
#  'total': 1916}

# %%
#Convierto el JSON a un DataFrame para verlo mejor
df = pd.DataFrame(data['data'])
df
# Out:
#            ticker   symbol                                     name   type  \
# 0        NDX.INDX      NDX                               Nasdaq 100  INDEX
# 1       GSPC.INDX     GSPC                            S&P 500 Index  INDEX
# 2        DJI.INDX      DJI             Dow Jones Industrial Average  INDEX
# 3    NAS100.OANDA   NAS100                               US Nas 100    cfd
# 4    SPX500.OANDA   SPX500                               US SPX 500    cfd
# ..            ...      ...                                      ...    ...
# 995  BUK350N.INDX  BUK350N                              Cboe UK 350  INDEX
# 996  BUK350P.INDX  BUK350P                              Cboe UK 350  INDEX
# 997   BUKACN.INDX   BUKACN                    Cboe UK All Companies  INDEX
# 998  BUKBISN.INDX  BUKBISN  Cboe UK Banking and Investment Services  INDEX
# 999   BUKBUS.INDX   BUKBUS         Cboe UK Business Services Sector  INDEX
#
#     currency         country exchange
# 0        USD   United States     INDX
# 1        USD   United States     INDX
# 2        USD   United States     INDX
# 3        USD   United States    OANDA
# 4        USD   United States    OANDA
# ..       ...             ...      ...
# 995      EUR  United Kingdom     INDX
# 996      EUR  United Kingdom     INDX
# 997      EUR  United Kingdom     INDX
# 998      EUR  United Kingdom     INDX
# 999      EUR  United Kingdom     INDX
#
# [1000 rows x 7 columns]

# %%
#filtramos para ver solo los índices que nos interesan, en este caso el de la bolsa española
df_Spain  = df[df["country"] == "Spain"]
df_Spain
# Out:
#                ticker  symbol                   name   type currency country  \
# 34     ES35.ICMARKETS    ES35  Spanish IBEX 35 Index    cfd      EUR   Spain
# 35   ES35.PEPPERSTONE    ES35         Spain 35 Index    cfd      EUR   Spain
# 108         IBEX.INDX    IBEX          IBEX 35 Index  INDEX      EUR   Spain
# 918       IBEXTR.INDX  IBEXTR      IBEX Total Return  INDEX      EUR   Spain
#
#         exchange
# 34     ICMARKETS
# 35   PEPPERSTONE
# 108         INDX
# 918         INDX

# %% [markdown]
# De los 4 tickers que tenemos de España, vamos a seleccionar el ticker "IBEX.INDX" para nuestro análisis ya que los dos primeros son cfds que tienen como archivo subyacente el propio índice. Entre los dos índices que nos ofrece, el Total Return supone una estrategia que consiste en que se hayan reinvertido todos los dividendos dados por las empresas que lo forman. Esto no es del todo válido para nuestro análisis ya que las cotizaciones de nuestras empresas las vamos a estudiar descontando los dividendos.
#
# Ya que tenemos el índice seleccionado, vamos a ver cuales son las empresas que lo componen, para ello necesitamos la URL de las acciones y filtrar por el índice.

# %%
#definimos la url del índice que nos interesa para sacar el listado de empresas que lo componen, en este caso el IBEX35
URL_Empresas = f"https://api.profit.com/data-api/fundamentals/indexes/index_constituents/IBEX?token=" + api_key
URL_Empresas
# Out:
# 'https://api.profit.com/data-api/fundamentals/indexes/index_constituents/IBEX?token=978336172b8c4b29960d9366896f6ef7'

# %%
response = requests.get(URL_Empresas)
if response.status_code == 200:
    data_empresas = response.json()
else:
    print(f"Error: {response.status_code} - {response.text}")
#Hacemos lo mismo que antes, convertimos el JSON a un DataFrame para verlo mejor
data_empresas
# Out:
# {'0': {'Ticker': 'GRF.MC',
#   'Code': 'GRF',
#   'Exchange': 'MC',
#   'Name': 'Grifols S.A.',
#   'Sector': 'Healthcare',
#   'Industry': 'Drug Manufacturers - General',
#   'Weight': None},
#  '1': {'Ticker': 'IDR.MC',
#   'Code': 'IDR',
#   'Exchange': 'MC',
#   'Name': 'Indra A',
#   'Sector': 'Technology',
#   'Industry': 'Information Technology Services',
#   'Weight': None},
#  '2': {'Ticker': 'CABK.MC',
#   'Code': 'CABK',
#   'Exchange': 'MC',
#   'Name': 'Caixabank SA',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Regional',
#   'Weight': None},
#  '3': {'Ticker': 'REP.MC',
#   'Code': 'REP',
#   'Exchange': 'MC',
#   'Name': 'Repsol',
#   'Sector': 'Energy',
#   'Industry': 'Oil & Gas Integrated',
#   'Weight': None},
#  '4': {'Ticker': 'TEF.MC',
#   'Code': 'TEF',
#   'Exchange': 'MC',
#   'Name': 'Telefonica',
#   'Sector': 'Communication Services',
#   'Industry': 'Telecom Services',
#   'Weight': None},
#  '5': {'Ticker': 'BKT.MC',
#   'Code': 'BKT',
#   'Exchange': 'MC',
#   'Name': 'Bankinter',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Regional',
#   'Weight': None},
#  '6': {'Ticker': 'AMS.MC',
#   'Code': 'AMS',
#   'Exchange': 'MC',
#   'Name': 'Amadeus IT Group S.A.',
#   'Sector': 'Technology',
#   'Industry': 'Information Technology Services',
#   'Weight': None},
#  '7': {'Ticker': 'MAP.MC',
#   'Code': 'MAP',
#   'Exchange': 'MC',
#   'Name': 'Mapfre',
#   'Sector': 'Financial Services',
#   'Industry': 'Insurance - Diversified',
#   'Weight': None},
#  '8': {'Ticker': 'ITX.MC',
#   'Code': 'ITX',
#   'Exchange': 'MC',
#   'Name': 'Industria de Diseno Textil SA',
#   'Sector': 'Consumer Cyclical',
#   'Industry': 'Apparel Retail',
#   'Weight': None},
#  '9': {'Ticker': 'SAB.MC',
#   'Code': 'SAB',
#   'Exchange': 'MC',
#   'Name': 'Banco de Sabadell S.A',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Diversified',
#   'Weight': None},
#  '10': {'Ticker': 'MTS.MC',
#   'Code': 'MTS',
#   'Exchange': 'MC',
#   'Name': 'ArcelorMittal SA',
#   'Sector': 'Basic Materials',
#   'Industry': 'Steel',
#   'Weight': None},
#  '11': {'Ticker': 'ANA.MC',
#   'Code': 'ANA',
#   'Exchange': 'MC',
#   'Name': 'Acciona',
#   'Sector': 'Industrials',
#   'Industry': 'Engineering & Construction',
#   'Weight': None},
#  '12': {'Ticker': 'SAN.MC',
#   'Code': 'SAN',
#   'Exchange': 'MC',
#   'Name': 'Banco Santander',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Diversified',
#   'Weight': None},
#  '13': {'Ticker': 'ENG.MC',
#   'Code': 'ENG',
#   'Exchange': 'MC',
#   'Name': 'Enagás S.A.',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Regulated Gas',
#   'Weight': None},
#  '14': {'Ticker': 'ACX.MC',
#   'Code': 'ACX',
#   'Exchange': 'MC',
#   'Name': 'Acerinox',
#   'Sector': 'Basic Materials',
#   'Industry': 'Steel',
#   'Weight': None},
#  '15': {'Ticker': 'IAG.MC',
#   'Code': 'IAG',
#   'Exchange': 'MC',
#   'Name': 'International Consolidated Airlines Group S.A',
#   'Sector': 'Industrials',
#   'Industry': 'Airlines',
#   'Weight': None},
#  '16': {'Ticker': 'FER.MC',
#   'Code': 'FER',
#   'Exchange': 'MC',
#   'Name': 'Ferrovial S.A.',
#   'Sector': 'Industrials',
#   'Industry': 'Infrastructure Operations',
#   'Weight': None},
#  '17': {'Ticker': 'IBE.MC',
#   'Code': 'IBE',
#   'Exchange': 'MC',
#   'Name': 'Iberdrola S.A.',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Diversified',
#   'Weight': None},
#  '18': {'Ticker': 'ACS.MC',
#   'Code': 'ACS',
#   'Exchange': 'MC',
#   'Name': 'ACS Actividades de Construccion y Servicios SA',
#   'Sector': 'Industrials',
#   'Industry': 'Engineering & Construction',
#   'Weight': None},
#  '19': {'Ticker': 'BBVA.MC',
#   'Code': 'BBVA',
#   'Exchange': 'MC',
#   'Name': 'Banco Bilbao Vizcaya Argentaria SA',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Diversified',
#   'Weight': None},
#  '20': {'Ticker': 'ELE.MC',
#   'Code': 'ELE',
#   'Exchange': 'MC',
#   'Name': 'Endesa SA',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Regulated Electric',
#   'Weight': None},
#  '21': {'Ticker': 'SLR.MC',
#   'Code': 'SLR',
#   'Exchange': 'MC',
#   'Name': 'Solaria Energía y Medio Ambiente S.A',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Renewable',
#   'Weight': None},
#  '22': {'Ticker': 'AENA.MC',
#   'Code': 'AENA',
#   'Exchange': 'MC',
#   'Name': 'Aena SA',
#   'Sector': 'Industrials',
#   'Industry': 'Airports & Air Services',
#   'Weight': None},
#  '23': {'Ticker': 'CLNX.MC',
#   'Code': 'CLNX',
#   'Exchange': 'MC',
#   'Name': 'Cellnex Telecom SA',
#   'Sector': 'Real Estate',
#   'Industry': 'Real Estate Services',
#   'Weight': None},
#  '24': {'Ticker': 'LOG.MC',
#   'Code': 'LOG',
#   'Exchange': 'MC',
#   'Name': 'Cia de Distribucion Integral',
#   'Sector': 'Industrials',
#   'Industry': 'Integrated Freight & Logistics',
#   'Weight': None},
#  '25': {'Ticker': 'FDR.MC',
#   'Code': 'FDR',
#   'Exchange': 'MC',
#   'Name': 'Fluidra',
#   'Sector': 'Industrials',
#   'Industry': 'Specialty Industrial Machinery',
#   'Weight': None},
#  '26': {'Ticker': 'COL.MC',
#   'Code': 'COL',
#   'Exchange': 'MC',
#   'Name': 'Inmobiliaria Colonial SA',
#   'Sector': 'Real Estate',
#   'Industry': 'REIT - Office',
#   'Weight': None},
#  '27': {'Ticker': 'ROVI.MC',
#   'Code': 'ROVI',
#   'Exchange': 'MC',
#   'Name': 'Laboratorios Farmaceuticos ROVI',
#   'Sector': 'Healthcare',
#   'Industry': 'Drug Manufacturers - Specialty & Generic',
#   'Weight': None},
#  '28': {'Ticker': 'MRL.MC',
#   'Code': 'MRL',
#   'Exchange': 'MC',
#   'Name': 'Merlin Properties SOCIMI SA',
#   'Sector': 'Real Estate',
#   'Industry': 'REIT - Office',
#   'Weight': None},
#  '29': {'Ticker': 'SCYR.MC',
#   'Code': 'SCYR',
#   'Exchange': 'MC',
#   'Name': 'Sacyr SA',
#   'Sector': 'Industrials',
#   'Industry': 'Engineering & Construction',
#   'Weight': None},
#  '30': {'Ticker': 'UNI.MC',
#   'Code': 'UNI',
#   'Exchange': 'MC',
#   'Name': 'Unicaja Banco SA',
#   'Sector': 'Financial Services',
#   'Industry': 'Banks - Regional',
#   'Weight': None},
#  '31': {'Ticker': 'NTGY.MC',
#   'Code': 'NTGY',
#   'Exchange': 'MC',
#   'Name': 'Naturgy Energy Group SA',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Regulated Gas',
#   'Weight': None},
#  '32': {'Ticker': 'ANE.MC',
#   'Code': 'ANE',
#   'Exchange': 'MC',
#   'Name': 'Corporacion Acciona Energias Renovables SA',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Renewable',
#   'Weight': None},
#  '33': {'Ticker': 'RED.MC',
#   'Code': 'RED',
#   'Exchange': 'MC',
#   'Name': 'Redeia Corporacion S.A.',
#   'Sector': 'Utilities',
#   'Industry': 'Utilities - Regulated Electric',
#   'Weight': None}}

# %%
#Convertimos el diccionario a un DataFrame para verlo mejor. como es un diccionario con indice usaremos la primera parte de cada clave como índice
df_empresas = pd.DataFrame.from_dict(data_empresas, orient='index')
df_empresas.head(5)
# Out:
#     Ticker  Code Exchange          Name                  Sector  \
# 0   GRF.MC   GRF       MC  Grifols S.A.              Healthcare
# 1   IDR.MC   IDR       MC       Indra A              Technology
# 2  CABK.MC  CABK       MC  Caixabank SA      Financial Services
# 3   REP.MC   REP       MC        Repsol                  Energy
# 4   TEF.MC   TEF       MC    Telefonica  Communication Services
#
#                           Industry Weight
# 0     Drug Manufacturers - General   None
# 1  Information Technology Services   None
# 2                 Banks - Regional   None
# 3             Oil & Gas Integrated   None
# 4                 Telecom Services   None

# %% [markdown]
# Ya que tenemos los datos de las empresas y sabemos utilizar la api correctamente, vamos a empezar a generar las tablas que necesitaremos para nuestro análisis que son 4, de momento las voy a guardar en csv dentro de la carpeta:
#
# 1. Empresas
# Nombre
# Ticker
# Sector
# Subsector
#
# 2. Ratios financieros
# Año
# Ticker
# PER
# ROE
# EV/EBITDA
# Dividend Yield
# Beta
# Deuda/EBITDA
#
# 3. Cotizaciones
# Fecha
# Ticker
# Precio de cierre
# Variación
# Volumen
#
# 4. Dividendos
# Fecha
# Ticker
# Importe por acción

# %%
df_empresas.columns
# Out:
# Index(['Ticker', 'Code', 'Exchange', 'Name', 'Sector', 'Industry', 'Weight'], dtype='object')

# %%
#Para crear la tabla empresas, primero tenemos que filtrar el DataFrame para quedarnos solo con las columnas que nos interesan. En este caso, nos quedamos con el nombre de la empresa, su ticker, sector y subsector.
df_data_empresas = df_empresas[["Name", "Ticker", "Sector", "Industry"]]
df_data_empresas.rename(columns={"Industry":"Subsector"}, inplace=True)
df_data_empresas.head(5)
df_data_empresas.to_csv("Data/01.Empresas_IBEX35.csv", index=False)
# Out:
# C:\Users\ganad\AppData\Local\Temp\ipykernel_6916\1435054455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_empresas.rename(columns={"Industry":"Subsector"}, inplace=True)

# %%
#Para no usar la API cada vez que queramos ver los datos, cargamos de nuevo el dataframe desde el CSV
df_data_empresas = pd.read_csv("Data/01.Empresas_IBEX35.csv")
df_data_empresas
# Out:
#                                               Name   Ticker  \
# 0                                     Grifols S.A.   GRF.MC
# 1                                          Indra A   IDR.MC
# 2                                     Caixabank SA  CABK.MC
# 3                                           Repsol   REP.MC
# 4                                       Telefonica   TEF.MC
# 5                                        Bankinter   BKT.MC
# 6                            Amadeus IT Group S.A.   AMS.MC
# 7                                           Mapfre   MAP.MC
# 8                    Industria de Diseno Textil SA   ITX.MC
# 9                            Banco de Sabadell S.A   SAB.MC
# 10                                ArcelorMittal SA   MTS.MC
# 11                                         Acciona   ANA.MC
# 12                                 Banco Santander   SAN.MC
# 13                                     Enagás S.A.   ENG.MC
# 14                                        Acerinox   ACX.MC
# 15   International Consolidated Airlines Group S.A   IAG.MC
# 16                                  Ferrovial S.A.   FER.MC
# 17                                  Iberdrola S.A.   IBE.MC
# 18  ACS Actividades de Construccion y Servicios SA   ACS.MC
# 19              Banco Bilbao Vizcaya Argentaria SA  BBVA.MC
# 20                                       Endesa SA   ELE.MC
# 21            Solaria Energía y Medio Ambiente S.A   SLR.MC
# 22                                         Aena SA  AENA.MC
# 23                              Cellnex Telecom SA  CLNX.MC
# 24                    Cia de Distribucion Integral   LOG.MC
# 25                                         Fluidra   FDR.MC
# 26                        Inmobiliaria Colonial SA   COL.MC
# 27                 Laboratorios Farmaceuticos ROVI  ROVI.MC
# 28                     Merlin Properties SOCIMI SA   MRL.MC
# 29                                        Sacyr SA  SCYR.MC
# 30                                Unicaja Banco SA   UNI.MC
# 31                         Naturgy Energy Group SA  NTGY.MC
# 32      Corporacion Acciona Energias Renovables SA   ANE.MC
# 33                         Redeia Corporacion S.A.   RED.MC
#
#                     Sector                                 Subsector
# 0               Healthcare              Drug Manufacturers - General
# 1               Technology           Information Technology Services
# 2       Financial Services                          Banks - Regional
# 3                   Energy                      Oil & Gas Integrated
# 4   Communication Services                          Telecom Services
# 5       Financial Services                          Banks - Regional
# 6               Technology           Information Technology Services
# 7       Financial Services                   Insurance - Diversified
# 8        Consumer Cyclical                            Apparel Retail
# 9       Financial Services                       Banks - Diversified
# 10         Basic Materials                                     Steel
# 11             Industrials                Engineering & Construction
# 12      Financial Services                       Banks - Diversified
# 13               Utilities                 Utilities - Regulated Gas
# 14         Basic Materials                                     Steel
# 15             Industrials                                  Airlines
# 16             Industrials                 Infrastructure Operations
# 17               Utilities                   Utilities - Diversified
# 18             Industrials                Engineering & Construction
# 19      Financial Services                       Banks - Diversified
# 20               Utilities            Utilities - Regulated Electric
# 21               Utilities                     Utilities - Renewable
# 22             Industrials                   Airports & Air Services
# 23             Real Estate                      Real Estate Services
# 24             Industrials            Integrated Freight & Logistics
# 25             Industrials            Specialty Industrial Machinery
# 26             Real Estate                             REIT - Office
# 27              Healthcare  Drug Manufacturers - Specialty & Generic
# 28             Real Estate                             REIT - Office
# 29             Industrials                Engineering & Construction
# 30      Financial Services                          Banks - Regional
# 31               Utilities                 Utilities - Regulated Gas
# 32               Utilities                     Utilities - Renewable
# 33               Utilities            Utilities - Regulated Electric

# %%
#Ahora que tenemos el listado de empresas, vamos a sacar los tickers de cada una de ellas
lista_tickers = df_data_empresas["Ticker"].tolist()
lista_tickers
# Out:
# ['GRF.MC',
#  'IDR.MC',
#  'CABK.MC',
#  'REP.MC',
#  'TEF.MC',
#  'BKT.MC',
#  'AMS.MC',
#  'MAP.MC',
#  'ITX.MC',
#  'SAB.MC',
#  'MTS.MC',
#  'ANA.MC',
#  'SAN.MC',
#  'ENG.MC',
#  'ACX.MC',
#  'IAG.MC',
#  'FER.MC',
#  'IBE.MC',
#  'ACS.MC',
#  'BBVA.MC',
#  'ELE.MC',
#  'SLR.MC',
#  'AENA.MC',
#  'CLNX.MC',
#  'LOG.MC',
#  'FDR.MC',
#  'COL.MC',
#  'ROVI.MC',
#  'MRL.MC',
#  'SCYR.MC',
#  'UNI.MC',
#  'NTGY.MC',
#  'ANE.MC',
#  'RED.MC']

# %%
#Vamos a sacar la cotizaición de una de las empresas, por ejemplo, CABK para ver el tipo de dato que nos devuelve
ticker = "^IBEX"
cabk = yf.Ticker(ticker)
data = cabk.history(start = "2020-01-01")
#obtenemos los 5 ultimos datos
data.tail(5)
# Out:
#                                    Open          High           Low  \
# Date
# 2025-04-11 00:00:00+02:00  12364.200195  12419.000000  12157.400391
# 2025-04-14 00:00:00+02:00  12540.599609  12633.799805  12419.500000
# 2025-04-15 00:00:00+02:00  12652.400391  12881.099609  12626.599609
# 2025-04-16 00:00:00+02:00  12848.500000  12942.099609  12756.099609
# 2025-04-17 00:00:00+02:00  12934.000000  12965.700195  12852.000000
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2025-04-11 00:00:00+02:00  12286.000000  135190900        0.0           0.0
# 2025-04-14 00:00:00+02:00  12609.799805  120617900        0.0           0.0
# 2025-04-15 00:00:00+02:00  12879.299805  124665000        0.0           0.0
# 2025-04-16 00:00:00+02:00  12942.099609  127312200        0.0           0.0
# 2025-04-17 00:00:00+02:00  12918.000000  118973300        0.0           0.0

# %%
#Vamos a crear un bucle para sacar la cotización de todas las empresas del IBEX35 y guardarlas en un DataFrame.
#Definimos la fecha de inicio ya que la de fin es la fecha de hoy
start_date = "2020-01-01"
#Generamos un DataFrame vacío para guardar los datos
df_cotizaciones = pd.DataFrame()
for ticker in lista_tickers:
    ticker_yahoo = yf.Ticker(ticker)
    #sacamos la cotización desde la fecha de inicio hasta hoy
    data = ticker_yahoo.history(start = start_date).reset_index()
    #le metemos el ticker como columna al DataFrame
    data["ticker"] = ticker
    #Añadimos una columna de variación porcentual de la cotización usando el método pct_change()
    data["Variación"] = data["Close"].pct_change()
    #Cambiamos el tipo de la columna "Date" a datetime y formato (YYYY/MM/DD) para que sea más fácil de trabajar
    data["Date"] = pd.to_datetime(data["Date"], format="%Y-%m-%d")
    #Concatenamos los datos de cada empresa al DataFrame vacío que hemos creado antes
    df_cotizaciones = pd.concat([df_cotizaciones, data])


#Vemos los datos que hemos sacado
df_cotizaciones
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2020-01-02 00:00:00+01:00  30.970768  31.117363  30.814399  30.990313
# 1    2020-01-03 00:00:00+01:00  30.716669  31.039179  30.716669  31.019632
# 2    2020-01-06 00:00:00+01:00  30.843717  31.166228  30.736215  31.009859
# 3    2020-01-07 00:00:00+01:00  31.088042  31.928522  31.088042  31.860111
# 4    2020-01-08 00:00:00+01:00  31.801477  31.987164  31.645109  31.830795
# ...                        ...        ...        ...        ...        ...
# 1352 2025-04-11 00:00:00+02:00  18.340000  18.719999  18.250000  18.530001
# 1353 2025-04-14 00:00:00+02:00  18.709999  18.719999  18.459999  18.670000
# 1354 2025-04-15 00:00:00+02:00  18.790001  19.090000  18.700001  19.080000
# 1355 2025-04-16 00:00:00+02:00  19.230000  19.250000  19.000000  19.090000
# 1356 2025-04-17 00:00:00+02:00  19.059999  19.290001  18.910000  19.200001
#
#        Volume  Dividends  Stock Splits  ticker  Variación
# 0      392672        0.0           0.0  GRF.MC        NaN
# 1      641127        0.0           0.0  GRF.MC   0.000946
# 2      386910        0.0           0.0  GRF.MC  -0.000315
# 3     2090693        0.0           0.0  GRF.MC   0.027419
# 4      609008        0.0           0.0  GRF.MC  -0.000920
# ...       ...        ...           ...     ...        ...
# 1352  1131080        0.0           0.0  RED.MC   0.017573
# 1353   685584        0.0           0.0  RED.MC   0.007555
# 1354   885114        0.0           0.0  RED.MC   0.021960
# 1355   876076        0.0           0.0  RED.MC   0.000524
# 1356   607021        0.0           0.0  RED.MC   0.005762
#
# [45754 rows x 10 columns]

# %%
df_cotizaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45754 entries, 0 to 1356
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          45754 non-null  datetime64[ns, Europe/Madrid]
#  1   Open          45754 non-null  float64
#  2   High          45754 non-null  float64
#  3   Low           45754 non-null  float64
#  4   Close         45754 non-null  float64
#  5   Volume        45754 non-null  int64
#  6   Dividends     45754 non-null  float64
#  7   Stock Splits  45754 non-null  float64
#  8   ticker        45754 non-null  object
#  9   Variación     45720 non-null  float64
# dtypes: datetime64[ns, Europe/Madrid](1), float64(7), int64(1), object(1)
# memory usage: 3.8+ MB

# %% [markdown]
# Para tener más limpio el código y posteriormente poder usarlo de forma más sencilla, voy a crear una función que haga todo lo anterior dándole una fecha de inicio y un listado de empresas

# %%
#Creamos la función para que nos de la cotización de un listado de empresas desde una fecha hasta el día de hoy y añada las del IBEX35
def get_cotizaciones_Ibex(tickers, start_date="2020-01-01"):
    tickers.append("^IBEX")
    df_cotizaciones = pd.DataFrame()
    for ticker in tickers:
        ticker_yahoo = yf.Ticker(ticker)
        #sacamos la cotización desde la fecha de inicio hasta hoy
        data = ticker_yahoo.history(start = start_date).reset_index()
        #le metemos el ticker como columna al DataFrame
        data["ticker"] = ticker
        data.drop_duplicates(inplace=True)
        #Añadimos una columna de variación porcentual de la cotización usando el método pct_change()
        data["Variación"] = data["Close"].pct_change()
        #Cambiamos el tipo de la columna "Date" a datetime y formato (YYYY/MM/DD) para que sea más fácil de trabajar
        data["Date"] = pd.to_datetime(data["Date"], format="%Y-%m-%d")
        #Concatenamos los datos de cada empresa al DataFrame vacío que hemos creado antes
        df_cotizaciones = pd.concat([df_cotizaciones, data])

    #Vamos a redondear a 4 dígitos la variación porcentual para que no ocupe tanto espacio y la columna de cierrre a 2 decimales
    df_cotizaciones["Variación"] = df_cotizaciones["Variación"].round(4)
    df_cotizaciones["Close"] = df_cotizaciones["Close"].round(2)
    #Eliminamos las columnas que no nos interesan, en este caso "Dividends", "Stock Splits","Open","High","Low"
    df_cotizaciones.drop(columns=["Dividends", "Stock Splits","Open","High","Low"], inplace=True)
    #Reordenamos las columnas para que quede esté el ticker la primera columna y el volumen la última
    df_cotizaciones = df_cotizaciones[["ticker","Date","Close","Volume","Variación"]]
    return df_cotizaciones.to_csv("Data/03.Cotizaciones_IBEX35.csv", index=False)

# %%
#Ejecutamos la función para que nos de la cotización de todas las empresas del IBEX35 desde el 2020-01-01 hasta hoy
get_cotizaciones_Ibex(lista_tickers)

# %%
df_cot = pd.read_csv("Data/03.Cotizaciones_IBEX35.csv")

# %%
df_cot["ticker"].unique()
# Out:
# array(['GRF.MC', 'IDR.MC', 'CABK.MC', 'REP.MC', 'TEF.MC', 'BKT.MC',
#        'AMS.MC', 'MAP.MC', 'ITX.MC', 'SAB.MC', 'MTS.MC', 'ANA.MC',
#        'SAN.MC', 'ENG.MC', 'ACX.MC', 'IAG.MC', 'FER.MC', 'IBE.MC',
#        'ACS.MC', 'BBVA.MC', 'ELE.MC', 'SLR.MC', 'AENA.MC', 'CLNX.MC',
#        'LOG.MC', 'FDR.MC', 'COL.MC', 'ROVI.MC', 'MRL.MC', 'SCYR.MC',
#        'UNI.MC', 'NTGY.MC', 'ANE.MC', 'RED.MC', '^IBEX'], dtype=object)

# %%
#Haré un pequeño análisis de los datos para comprobar que todo ha ido bien y ver si hay algún error en los datos.
df_cot.describe(include="object")
# Out:
#         ticker                       Date
# count    47111                      47111
# unique      35                       1357
# top     GRF.MC  2025-04-17 00:00:00+02:00
# freq      1357                         35

# %%
df_cot.groupby("ticker").agg({"Close":"count"}).sort_values(by="Close", ascending=False)
# Out:
#          Close
# ticker
# ACS.MC    1357
# ACX.MC    1357
# AENA.MC   1357
# AMS.MC    1357
# ANA.MC    1357
# BBVA.MC   1357
# BKT.MC    1357
# CLNX.MC   1357
# CABK.MC   1357
# COL.MC    1357
# ELE.MC    1357
# GRF.MC    1357
# ENG.MC    1357
# FDR.MC    1357
# FER.MC    1357
# IBE.MC    1357
# IAG.MC    1357
# IDR.MC    1357
# ITX.MC    1357
# ROVI.MC   1357
# LOG.MC    1357
# MAP.MC    1357
# MRL.MC    1357
# MTS.MC    1357
# NTGY.MC   1357
# RED.MC    1357
# REP.MC    1357
# SLR.MC    1357
# SAB.MC    1357
# SAN.MC    1357
# SCYR.MC   1357
# UNI.MC    1357
# TEF.MC    1357
# ^IBEX     1357
# ANE.MC     973

# %%
df_cot.isnull().sum()
# Out:
# ticker        0
# Date          0
# Close         0
# Volume        0
# Variación    35
# dtype: int64
